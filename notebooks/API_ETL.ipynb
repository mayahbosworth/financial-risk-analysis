# %% [markdown]
# # AlphaVantage API

# %% [markdown]
# ### Initialize

# %%
import requests
import pandas as pd
import os
from dotenv import load_dotenv
from datetime import datetime, timedelta
import time

# %%
load_dotenv()

apikey = os.getenv("apikey")

# %%
base_url = "https://www.alphavantage.co/query?"

# %%
symbols = [
    'IBM',    # Technology / Services
    'AAPL',   # Apple - Technology
    'MSFT',   # Microsoft - Technology
    'AMZN',   # Amazon - Consumer Goods / Technology
    'GOOGL',  # Alphabet (Google) - Technology
    'META',     # Meta (Facebook) - Technology
    'JPM',    # JPMorgan Chase - Financial
    'V',      # Visa - Financial
    'PG',     # Procter & Gamble - Consumer Goods
    'UNH',    # UnitedHealth - Healthcare
    'JNJ',    # Johnson & Johnson - Healthcare
    'XOM',    # ExxonMobil - Energy
    'CVX',    # Chevron - Energy
    'TSLA',   # Tesla - Automotive / Energy
    'WMT',    # Walmart - Retail
    'BAC',    # Bank of America - Financial
    'INTC',   # Intel - Technology
    'CSCO',   # Cisco Systems - Technology
    'KO',     # Coca-Cola - Consumer Goods
    'PEP',    # PepsiCo - Consumer Goods
    'MCD',    # McDonald's - Consumer Services
    'MMM',    # 3M - Conglomerate
    'BA',     # Boeing - Aerospace
    'CAT',    # Caterpillar - Heavy Equipment
    'LMT',    # Lockheed Martin - Aerospace and Defense
    'GS',     # Goldman Sachs - Financial
    'DIS',    # Disney - Media and Entertainment
    'PFE',    # Pfizer - Healthcare
    'MRK',    # Merck - Healthcare
    'GE',     # General Electric - Conglomerate
    'NKE',    # Nike - Apparel
    'SBUX',   # Starbucks - Specialty Eateries
    'NFLX',   # Netflix - Media
    'ORCL',   # Oracle - Technology
    'AMD',    # Advanced Micro Devices - Technology
    'NVDA',   # NVIDIA - Technology
    'F',      # Ford - Automotive
    'GM',     # General Motors - Automotive
    'UPS',    # United Parcel Service - Logistics
    'FDX',    # FedEx - Logistics
    'LYFT',   # Lyft - Ride-Sharing
    'UBER'    # Uber - Ride-Sharing
]

# %% [markdown]
# ### Balance Sheet

# %%
dfs = []
for symbol in symbols:
    balance_sheet_url = f"{base_url}function=BALANCE_SHEET&symbol={symbol}&apikey={apikey}"
    balance_sheet_response = requests.get(balance_sheet_url)

    # Check if the request was successful
    if balance_sheet_response.status_code == 200:
        # Parse JSON response
        balance_sheet_data = balance_sheet_response.json()
        
        # Initialize lists to collect data
        fiscal_date_endings = []
        total_assets = []
        total_liabilities = []
        total_shareholder_equity = []
        
        # Extract quarterly reports data
        for report in balance_sheet_data["quarterlyReports"]:
            fiscal_date_endings.append(report['fiscalDateEnding'])
            total_assets.append(report['totalAssets'])
            total_liabilities.append(report.get('totalLiabilities', ""))
            total_shareholder_equity.append(report.get('totalShareholderEquity', ""))
        
        # Create DataFrame for the current symbol
        quarterly_reports_df = pd.DataFrame({
            'Symbol': [symbol] * len(fiscal_date_endings),
            'Fiscal Date Ending': fiscal_date_endings,
            'Total Assets': total_assets,
            'Total Liabilities': total_liabilities,
            'Total Shareholder Equity': total_shareholder_equity
        })
        
        # Append the DataFrame to the list
        dfs.append(quarterly_reports_df)

# Concatenate all DataFrames in the list
quarterly_reports_df = pd.concat(dfs, ignore_index=True)

quarterly_reports_df
# Out:
#      Symbol Fiscal Date Ending  Total Assets Total Liabilities  \
# 0       IBM         2024-03-31  137169000000      113836000000
# 1       IBM         2023-12-31  135241000000      112628000000
# 2       IBM         2023-09-30  129321000000      106165000000
# 3       IBM         2023-06-30  132213000000      109942000000
# 4       IBM         2023-03-31  133637000000      111964000000
# ...     ...                ...           ...               ...
# 2330   UBER         2020-03-31   30090000000       17772000000
# 2331   UBER         2019-12-31   31761000000       16578000000
# 2332   UBER         2019-09-30   32292000000       16241000000
# 2333   UBER         2019-06-30   30980000000       15072000000
# 2334   UBER         2019-03-31   24390000000       18602000000
#
#      Total Shareholder Equity
# 0                 23261000000
# 1                 22533000000
# 2                 23081000000
# 3                 22201000000
# 4                 21604000000
# ...                       ...
# 2330              11342000000
# 2331              14190000000
# 2332              15062000000
# 2333              15922000000
# 2334              -8432000000
#
# [2335 rows x 5 columns]

# %% [markdown]
# ### Income Statement

# %%
dfs = []

for symbol in symbols:
    income_statement_url = f"{base_url}function=INCOME_STATEMENT&symbol={symbol}&apikey={apikey}"
    try:
        income_statement_response = requests.get(income_statement_url)
        income_statement_response.raise_for_status()  # Raises an HTTPError for bad responses
        income_statement_data = income_statement_response.json()
    except requests.RequestException as e:
        print(f"Request failed for {symbol}: {e}")
        continue
    
    fiscal_date_endings = []
    total_revenue = []
    total_expenses = []
    ebit = []
    
    for income_report in income_statement_data["quarterlyReports"]:
        fiscal_date_endings.append(income_report['fiscalDateEnding'])
        
        # Safely convert revenue to float
        try:
            total_revenue.append(float(income_report['totalRevenue']))
        except ValueError:
            total_revenue.append(0)
        
        # Safely calculate total expenses
        expenses_components = ['costOfRevenue', 'operatingExpenses', 'interestAndDebtExpense',
                               'depreciationAndAmortization', 'incomeTaxExpense']
        expense_total = 0
        for component in expenses_components:
            try:
                expense_total += float(income_report.get(component, 0) or 0)
            except ValueError:
                continue  # Skip component if conversion fails
        
        total_expenses.append(expense_total)
        ebit.append(income_report.get('ebit', ""))
    
    # Create DataFrame for the current symbol
    income_statements_df = pd.DataFrame({
        'Symbol': [symbol] * len(fiscal_date_endings),
        'Fiscal Date Ending': fiscal_date_endings,
        'Total Revenue': total_revenue,
        'Total Expenses': total_expenses,
        'EBIT': ebit
    })
    
    # Append the DataFrame to the list
    dfs.append(income_statements_df)

# Concatenate all DataFrames in the list
income_statements_df = pd.concat(dfs, ignore_index=True)

income_statements_df
# Out:
#      Symbol Fiscal Date Ending  Total Revenue  Total Expenses         EBIT
# 0       IBM         2024-03-31   1.446200e+10    1.490400e+10   1535000000
# 1       IBM         2023-12-31   1.738100e+10    1.499500e+10   4167000000
# 2       IBM         2023-09-30   1.475200e+10    1.390100e+10   2275000000
# 3       IBM         2023-06-30   1.547500e+10    1.489000e+10   2425000000
# 4       IBM         2023-03-31   1.425200e+10    1.503400e+10   1418000000
# ...     ...                ...            ...             ...          ...
# 2491   UBER         2019-03-31   3.099000e+09    5.417000e+09   -776000000
# 2492   UBER         2018-12-31   2.137000e+09    3.814000e+09  -1014000000
# 2493   UBER         2018-09-30   2.944000e+09    3.839000e+09   -824000000
# 2494   UBER         2018-06-30   2.768000e+09    3.633000e+09   -690000000
# 2495   UBER         2018-03-31   2.584000e+09    3.726000e+09   4456000000
#
# [2496 rows x 5 columns]

# %% [markdown]
# ### Cash Flow

# %%
dfs = []  

for symbol in symbols:
    cash_flow_url = f"{base_url}function=CASH_FLOW&symbol={symbol}&apikey={apikey}"
    try:
        cash_flow_response = requests.get(cash_flow_url)
        cash_flow_response.raise_for_status() 
        cash_flow_data = cash_flow_response.json()
    except requests.RequestException as e:
        print(f"Request failed for {symbol}: {e}")
        continue
    
    fiscal_date_endings = []
    investing_flows = []
    operating_flows = []
    financing_flows = []
    
    if "quarterlyReports" in cash_flow_data:
        for cash_flow_report in cash_flow_data["quarterlyReports"]:
            fiscal_date_endings.append(cash_flow_report['fiscalDateEnding'])

            try:
                financing_cash_flow = float(cash_flow_report.get("cashflowFromFinancing", 0) or 0)
                dividend_payout = float(cash_flow_report.get("dividendPayout", 0) or 0)
                financing_flows.append(financing_cash_flow + dividend_payout)
            except ValueError:
                financing_flows.append(0)
            
            try:
                capital_expenditures = float(cash_flow_report.get("capitalExpenditures", 0) or 0)
                investment_cash_flow = float(cash_flow_report.get("cashflowFromInvestment", 0) or 0)
                investing_flows.append(capital_expenditures + investment_cash_flow)
            except ValueError:
                investing_flows.append(0)
            
            try:
                operating_flows.append(float(cash_flow_report.get('operatingCashflow', 0) or 0))
            except ValueError:
                operating_flows.append(0)
        
        cash_flows_df = pd.DataFrame({
            'Symbol': [symbol] * len(fiscal_date_endings),
            'Fiscal Date Ending': fiscal_date_endings,
            'Operating Cash Flow': operating_flows,
            'Investing Cash Flow': investing_flows,
            'Financing Cash Flow': financing_flows
        })

        dfs.append(cash_flows_df)

all_cash_flows_df = pd.concat(dfs, ignore_index=True)
all_cash_flows_df
# Out:
#      Symbol Fiscal Date Ending  Operating Cash Flow  Investing Cash Flow  \
# 0       IBM         2024-03-31         4.168000e+09        -3.971000e+09
# 1       IBM         2023-12-31         4.463000e+09         3.136000e+09
# 2       IBM         2023-09-30         3.056000e+09        -1.672000e+09
# 3       IBM         2023-06-30         2.638000e+09         3.710000e+08
# 4       IBM         2023-03-31         3.774000e+09        -7.660000e+09
# ...     ...                ...                  ...                  ...
# 2399   UBER         2019-03-31        -7.220000e+08         3.330000e+08
# 2400   UBER         2018-12-31        -6.810000e+08         4.000000e+07
# 2401   UBER         2018-09-30        -4.100000e+08         8.000000e+07
# 2402   UBER         2018-06-30        -1.530000e+08         2.800000e+07
# 2403   UBER         2018-03-31        -2.970000e+08        -2.850000e+08
#
#       Financing Cash Flow
# 0            3.399000e+09
# 1           -9.700000e+07
# 2           -1.617000e+09
# 3           -1.220000e+09
# 4            7.205000e+09
# ...                   ...
# 2399         0.000000e+00
# 2400         0.000000e+00
# 2401         0.000000e+00
# 2402         0.000000e+00
# 2403         0.000000e+00
#
# [2404 rows x 5 columns]

# %% [markdown]
# ### Market Indicators

# %% [markdown]
# RSI:

# %%
load_dotenv()

apikey = os.getenv("apikey")

def fetch_rsi_daily(base_url, apikey, symbols, start_year, start_month):
    all_rsi_data = pd.DataFrame()
    
    for symbol in symbols:
        start_date = datetime(start_year, start_month, 1)
        current_date = datetime.now().replace(day=1)
        
        while start_date < current_date:
            month_str = start_date.strftime('%Y-%m')
            rsi_url = f'{base_url}function=RSI&symbol={symbol}&interval=daily&time_period=10&series_type=open&apikey={apikey}&month={month_str}'
            try:
                response = requests.get(rsi_url)
                response.raise_for_status()
                data = response.json()

                if 'Technical Analysis: RSI' in data:
                    rsi_data = data['Technical Analysis: RSI']
                    df = pd.DataFrame.from_dict(rsi_data, orient='index')
                    df.index = pd.to_datetime(df.index)
                    df.columns = ['Daily RSI']
                    df['Daily RSI'] = df['Daily RSI'].astype(float)
                    df['Symbol'] = symbol  
                    
                    all_rsi_data = pd.concat([all_rsi_data, df])
                else:
                    print(f"No RSI data available for {symbol} in {month_str}")
            except requests.RequestException as e:
                print(f"Failed to retrieve data for {symbol} in {month_str}: {e}")
            
            start_date = (start_date + timedelta(days=32)).replace(day=1)
            time.sleep(1) 
    
    return all_rsi_data

daily_rsi_data_df = fetch_rsi_daily(base_url, apikey, symbols, 2000, 1)

daily_rsi_data_df
# Out:
# No RSI data available for JNJ in 2017-07
#             Daily RSI Symbol
# 1999-11-15    43.1196    IBM
# 1999-11-16    39.6004    IBM
# 1999-11-17    40.5766    IBM
# 1999-11-18    38.1900    IBM
# 1999-11-19    55.0668    IBM
# ...               ...    ...
# 2024-05-06    50.1810   UBER
# 2024-05-07    55.9770   UBER
# 2024-05-08    34.0988   UBER
# 2024-05-09    41.3293   UBER
# 2024-05-10    44.2983   UBER
#
# [69256988 rows x 2 columns]

# %% [markdown]
# VWAP:

# %%
load_dotenv()

apikey = os.getenv("apikey")

def fetch_vwap_daily(base_url, apikey, symbols, start_year, start_month):
    all_vwap_data = pd.DataFrame()

    for symbol in symbols:
        start_date = datetime(start_year, start_month, 1)
        current_date = datetime.now().replace(day=1)
        
        while start_date < current_date:
            month_str = start_date.strftime('%Y-%m')
            vwap_url = f"{base_url}function=VWAP&symbol={symbol}&interval=60min&apikey={apikey}&month={month_str}"
            try:
                response = requests.get(vwap_url)
                response.raise_for_status()
                data = response.json()
            except requests.RequestException as e:
                print(f"Failed to retrieve VWAP data for {symbol} in {month_str}: {e}")
                continue

            if 'Technical Analysis: VWAP' in data:
                vwap_data = data['Technical Analysis: VWAP']
                df = pd.DataFrame.from_dict(vwap_data, orient='index')
                df.index = pd.to_datetime(df.index)
                df.columns = ['Daily VWAP']
                df['Daily VWAP'] = df['Daily VWAP'].astype(float)

                df['Symbol'] = symbol
                all_vwap_data = pd.concat([all_vwap_data, df])

            else:
                print(f"No VWAP data available for {symbol} in {month_str}")

            start_date += timedelta(days=32)
# No VWAP data available for META in 2008-11
# No VWAP data available for META in 2008-12
# No VWAP data available for META in 2009-01
# No VWAP data available for META in 2009-02
# No VWAP data available for META in 2009-03
# No VWAP data available for META in 2009-04
# No VWAP data available for META in 2009-05
# No VWAP data available for META in 2009-06
# No VWAP data available for META in 2009-07
# No VWAP data available for META in 2009-08
# No VWAP data available for META in 2009-09
# No VWAP data available for META in 2009-10
# No VWAP data available for META in 2009-11
# No VWAP data available for META in 2009-12
# No VWAP data available for META in 2010-01
# No VWAP data available for META in 2010-02
# No VWAP data available for META in 2010-03
# No VWAP data available for META in 2010-04
# No VWAP data available for META in 2010-05
# No VWAP data available for META in 2010-06
# No VWAP data available for META in 2010-07
# No VWAP data available for META in 2010-08
# No VWAP data available for META in 2010-09
# No VWAP data available for META in 2010-10
# No VWAP data available for META in 2010-11
# No VWAP data available for META in 2010-12
# No VWAP data available for META in 2011-01
# No VWAP data available for META in 2011-02
# No VWAP data available for META in 2011-03
# No VWAP data available for META in 2011-04
# No VWAP data available for META in 2011-05
# No VWAP data available for META in 2011-06
# No VWAP data available for META in 2011-07
# No VWAP data available for META in 2011-08
# No VWAP data available for META in 2011-09
# No VWAP data available for META in 2011-10
# No VWAP data available for META in 2011-11
# No VWAP data available for META in 2011-12
# No VWAP data available for META in 2012-01
# No VWAP data available for META in 2012-02
# No VWAP data available for META in 2012-03
# No VWAP data available for META in 2012-04
# No VWAP data available for V in 2000-01
# No VWAP data available for V in 2000-02
# No VWAP data available for V in 2000-03
# No VWAP data available for V in 2000-04
# No VWAP data available for V in 2000-05
# No VWAP data available for V in 2000-06
# No VWAP data available for V in 2000-07
# No VWAP data available for V in 2000-08
# No VWAP data available for V in 2000-09
# No VWAP data available for V in 2000-10
# No VWAP data available for V in 2000-11
# No VWAP data available for V in 2000-12
# No VWAP data available for V in 2001-01
# No VWAP data available for V in 2001-02
# No VWAP data available for V in 2001-03
# No VWAP data available for V in 2001-04
# No VWAP data available for V in 2001-05
# No VWAP data available for V in 2001-06
# No VWAP data available for V in 2001-07
# No VWAP data available for V in 2001-08
# No VWAP data available for V in 2001-09
# No VWAP data available for V in 2001-10
# No VWAP data available for V in 2001-11
# No VWAP data available for V in 2001-12
# No VWAP data available for V in 2002-01
# No VWAP data available for V in 2002-02
# No VWAP data available for V in 2002-03
# No VWAP data available for V in 2002-04
# No VWAP data available for V in 2002-05
# No VWAP data available for V in 2002-06
# No VWAP data available for V in 2002-07
# No VWAP data available for V in 2002-08
# No VWAP data available for V in 2002-09
# No VWAP data available for V in 2002-10
# No VWAP data available for V in 2002-11
# No VWAP data available for V in 2002-12
# No VWAP data available for V in 2003-01
# No VWAP data available for V in 2003-02
# No VWAP data available for V in 2003-03
# No VWAP data available for V in 2003-04
# No VWAP data available for V in 2003-05
# No VWAP data available for V in 2003-06
# No VWAP data available for V in 2003-07
# No VWAP data available for V in 2003-08
# No VWAP data available for V in 2003-09
# No VWAP data available for V in 2003-10
# No VWAP data available for V in 2003-11
# No VWAP data available for V in 2003-12
# No VWAP data available for V in 2004-01
# No VWAP data available for V in 2004-02
# No VWAP data available for V in 2004-03
# No VWAP data available for V in 2004-04
# No VWAP data available for V in 2004-05
# No VWAP data available for V in 2004-06
# No VWAP data available for V in 2004-07
# No VWAP data available for V in 2004-08
# No VWAP data available for V in 2004-09
# No VWAP data available for V in 2004-10
# No VWAP data available for V in 2004-11
# No VWAP data available for V in 2004-12
# No VWAP data available for V in 2005-01
# No VWAP data available for V in 2005-02
# No VWAP data available for V in 2005-03
# No VWAP data available for V in 2005-04
# No VWAP data available for V in 2005-05
# No VWAP data available for V in 2005-06
# No VWAP data available for V in 2005-07
# No VWAP data available for V in 2005-08
# No VWAP data available for V in 2005-09
# No VWAP data available for V in 2005-10
# No VWAP data available for V in 2005-11
# No VWAP data available for V in 2005-12
# No VWAP data available for V in 2006-01
# No VWAP data available for V in 2006-02
# No VWAP data available for V in 2006-03
# No VWAP data available for V in 2006-04
# No VWAP data available for V in 2006-05
# No VWAP data available for V in 2006-06
# No VWAP data available for V in 2006-07
# No VWAP data available for V in 2006-08
# No VWAP data available for V in 2006-09
# No VWAP data available for V in 2006-10
# No VWAP data available for V in 2006-11
# No VWAP data available for V in 2006-12
# No VWAP data available for V in 2007-01
# No VWAP data available for V in 2007-02
# No VWAP data available for V in 2007-03
# No VWAP data available for V in 2007-04
# No VWAP data available for V in 2007-05
# No VWAP data available for V in 2007-06
# No VWAP data available for V in 2007-07
# No VWAP data available for V in 2007-08
# No VWAP data available for V in 2007-09
# No VWAP data available for V in 2007-10
# No VWAP data available for V in 2007-11
# No VWAP data available for V in 2007-12
# No VWAP data available for V in 2008-01
# No VWAP data available for V in 2008-02
# No VWAP data available for CVX in 2000-01
# No VWAP data available for CVX in 2000-02
# No VWAP data available for CVX in 2000-03
# No VWAP data available for CVX in 2000-04
# No VWAP data available for CVX in 2000-05
# No VWAP data available for CVX in 2000-06
# No VWAP data available for CVX in 2000-07
# No VWAP data available for CVX in 2000-08
# No VWAP data available for CVX in 2000-09
# No VWAP data available for CVX in 2000-10
# No VWAP data available for CVX in 2000-11
# No VWAP data available for CVX in 2000-12
# No VWAP data available for CVX in 2001-01
# No VWAP data available for CVX in 2001-02
# No VWAP data available for CVX in 2001-03
# No VWAP data available for CVX in 2001-04
# No VWAP data available for CVX in 2001-05
# No VWAP data available for CVX in 2001-06
# No VWAP data available for CVX in 2001-07
# No VWAP data available for CVX in 2001-08
# No VWAP data available for CVX in 2001-09
# No VWAP data available for TSLA in 2000-01
# No VWAP data available for TSLA in 2000-02
# No VWAP data available for TSLA in 2000-03
# No VWAP data available for TSLA in 2000-04
# No VWAP data available for TSLA in 2000-05
# No VWAP data available for TSLA in 2000-06
# No VWAP data available for TSLA in 2000-07
# No VWAP data available for TSLA in 2000-08
# No VWAP data available for TSLA in 2000-09
# No VWAP data available for TSLA in 2000-10
# No VWAP data available for TSLA in 2000-11
# No VWAP data available for TSLA in 2000-12
# No VWAP data available for TSLA in 2001-01
# No VWAP data available for TSLA in 2007-07
# No VWAP data available for TSLA in 2007-08
# No VWAP data available for TSLA in 2007-09
# No VWAP data available for TSLA in 2007-10
# No VWAP data available for TSLA in 2007-11
# No VWAP data available for TSLA in 2007-12
# No VWAP data available for TSLA in 2008-01
# No VWAP data available for TSLA in 2008-02
# No VWAP data available for TSLA in 2008-03
# No VWAP data available for TSLA in 2008-04
# No VWAP data available for TSLA in 2008-05
# No VWAP data available for TSLA in 2008-06
# No VWAP data available for TSLA in 2008-07
# No VWAP data available for TSLA in 2008-08
# No VWAP data available for TSLA in 2008-09
# No VWAP data available for TSLA in 2008-10
# No VWAP data available for TSLA in 2008-11
# No VWAP data available for TSLA in 2008-12
# No VWAP data available for TSLA in 2009-01
# No VWAP data available for TSLA in 2009-02
# No VWAP data available for TSLA in 2009-03
# No VWAP data available for TSLA in 2009-04
# No VWAP data available for TSLA in 2009-05
# No VWAP data available for TSLA in 2009-06
# No VWAP data available for TSLA in 2009-07
# No VWAP data available for TSLA in 2009-08
# No VWAP data available for TSLA in 2009-09
# No VWAP data available for TSLA in 2009-10
# No VWAP data available for TSLA in 2009-11
# No VWAP data available for TSLA in 2009-12
# No VWAP data available for TSLA in 2010-01
# No VWAP data available for TSLA in 2010-02
# No VWAP data available for TSLA in 2010-03
# No VWAP data available for TSLA in 2010-04
# No VWAP data available for TSLA in 2010-05
# No VWAP data available for NFLX in 2000-01
# No VWAP data available for NFLX in 2000-02
# No VWAP data available for NFLX in 2000-03
# No VWAP data available for NFLX in 2000-04
# No VWAP data available for NFLX in 2000-05
# No VWAP data available for NFLX in 2000-06
# No VWAP data available for NFLX in 2000-07
# No VWAP data available for NFLX in 2000-08
# No VWAP data available for NFLX in 2000-09
# No VWAP data available for NFLX in 2000-10
# No VWAP data available for NFLX in 2000-11
# No VWAP data available for NFLX in 2000-12
# No VWAP data available for NFLX in 2001-01
# No VWAP data available for NFLX in 2001-02
# No VWAP data available for NFLX in 2001-03
# No VWAP data available for NFLX in 2001-04
# No VWAP data available for NFLX in 2001-05
# No VWAP data available for NFLX in 2001-06
# No VWAP data available for NFLX in 2001-07
# No VWAP data available for NFLX in 2001-08
# No VWAP data available for NFLX in 2001-09
# No VWAP data available for NFLX in 2001-10
# No VWAP data available for NFLX in 2001-11
# No VWAP data available for NFLX in 2001-12
# No VWAP data available for NFLX in 2002-01
# No VWAP data available for NFLX in 2002-02
# No VWAP data available for NFLX in 2002-03
# No VWAP data available for NFLX in 2002-04
# No VWAP data available for F in 2000-01
# No VWAP data available for F in 2000-02
# No VWAP data available for F in 2000-03
# No VWAP data available for F in 2000-04
# No VWAP data available for F in 2000-05
# No VWAP data available for F in 2000-06
# No VWAP data available for F in 2000-07
# No VWAP data available for F in 2000-08
# No VWAP data available for F in 2000-09
# No VWAP data available for F in 2000-10
# No VWAP data available for F in 2000-11
# No VWAP data available for F in 2000-12
# No VWAP data available for F in 2001-01
# No VWAP data available for F in 2001-02
# No VWAP data available for F in 2001-03
# No VWAP data available for F in 2001-04
# No VWAP data available for F in 2001-05
# No VWAP data available for F in 2001-06
# No VWAP data available for F in 2001-07
# No VWAP data available for F in 2001-08
# No VWAP data available for F in 2001-09
# No VWAP data available for F in 2001-10
# No VWAP data available for F in 2001-11
# No VWAP data available for F in 2001-12
# No VWAP data available for F in 2002-01
# No VWAP data available for F in 2002-02
# No VWAP data available for F in 2002-03
# No VWAP data available for F in 2002-04
# No VWAP data available for F in 2002-05
# No VWAP data available for F in 2002-06
# No VWAP data available for F in 2002-07
# No VWAP data available for F in 2002-08
# No VWAP data available for F in 2002-09
# No VWAP data available for F in 2002-10
# No VWAP data available for F in 2002-11
# No VWAP data available for F in 2002-12
# No VWAP data available for F in 2003-01
# No VWAP data available for F in 2003-02
# No VWAP data available for F in 2003-03
# No VWAP data available for F in 2003-04
# No VWAP data available for F in 2003-05
# No VWAP data available for F in 2003-06
# No VWAP data available for F in 2003-07
# No VWAP data available for F in 2003-08
# No VWAP data available for F in 2003-09
# No VWAP data available for F in 2003-10
# No VWAP data available for F in 2003-11
# No VWAP data available for F in 2003-12
# No VWAP data available for F in 2004-01
# No VWAP data available for F in 2004-02
# No VWAP data available for F in 2004-03
# No VWAP data available for F in 2004-04
# No VWAP data available for F in 2004-05
# No VWAP data available for F in 2004-06
# No VWAP data available for F in 2004-07
# No VWAP data available for F in 2004-08
# No VWAP data available for F in 2004-09
# No VWAP data available for F in 2004-10
# No VWAP data available for F in 2004-11
# No VWAP data available for F in 2004-12
# No VWAP data available for F in 2005-01
# No VWAP data available for F in 2005-02
# No VWAP data available for F in 2005-03
# No VWAP data available for F in 2005-04
# No VWAP data available for F in 2005-05
# No VWAP data available for F in 2005-06
# No VWAP data available for F in 2005-07
# No VWAP data available for F in 2005-08
# No VWAP data available for F in 2005-09
# No VWAP data available for F in 2005-10
# No VWAP data available for F in 2005-11
# No VWAP data available for F in 2005-12
# No VWAP data available for F in 2006-01
# No VWAP data available for F in 2006-02
# No VWAP data available for F in 2006-03
# No VWAP data available for F in 2006-04
# No VWAP data available for F in 2006-05
# No VWAP data available for F in 2006-06
# No VWAP data available for F in 2006-07
# No VWAP data available for F in 2006-08
# No VWAP data available for F in 2006-09
# No VWAP data available for F in 2006-10
# No VWAP data available for F in 2006-11
# No VWAP data available for F in 2006-12
# No VWAP data available for F in 2007-01
# No VWAP data available for F in 2007-02
# No VWAP data available for GM in 2000-01
# No VWAP data available for GM in 2000-02
# No VWAP data available for GM in 2000-03
# No VWAP data available for GM in 2000-04
# No VWAP data available for GM in 2000-05
# No VWAP data available for GM in 2000-06
# No VWAP data available for GM in 2000-07
# No VWAP data available for GM in 2000-08
# No VWAP data available for GM in 2000-09
# No VWAP data available for GM in 2000-10
# No VWAP data available for GM in 2000-11
# No VWAP data available for GM in 2000-12
# No VWAP data available for GM in 2001-01
# No VWAP data available for GM in 2001-02
# No VWAP data available for GM in 2001-03
# No VWAP data available for GM in 2001-04
# No VWAP data available for GM in 2001-05
# No VWAP data available for GM in 2001-06
# No VWAP data available for GM in 2008-07
# No VWAP data available for GM in 2008-08
# No VWAP data available for GM in 2008-09
# No VWAP data available for GM in 2008-10
# No VWAP data available for GM in 2008-11
# No VWAP data available for GM in 2008-12
# No VWAP data available for GM in 2009-01
# No VWAP data available for GM in 2009-02
# No VWAP data available for GM in 2009-03
# No VWAP data available for GM in 2009-04
# No VWAP data available for GM in 2009-05
# No VWAP data available for GM in 2009-06
# No VWAP data available for GM in 2009-07
# No VWAP data available for GM in 2009-08
# No VWAP data available for GM in 2009-09
# No VWAP data available for GM in 2009-10
# No VWAP data available for GM in 2009-11
# No VWAP data available for GM in 2009-12
# No VWAP data available for GM in 2010-01
# No VWAP data available for GM in 2010-02
# No VWAP data available for GM in 2010-03
# No VWAP data available for GM in 2010-04
# No VWAP data available for GM in 2010-05
# No VWAP data available for GM in 2010-06
# No VWAP data available for GM in 2010-07
# No VWAP data available for GM in 2010-08
# No VWAP data available for GM in 2010-09
# No VWAP data available for GM in 2010-10
# No VWAP data available for LYFT in 2000-01
# No VWAP data available for LYFT in 2000-02
# No VWAP data available for LYFT in 2000-03
# No VWAP data available for LYFT in 2000-04
# No VWAP data available for LYFT in 2000-05
# No VWAP data available for LYFT in 2000-06
# No VWAP data available for LYFT in 2000-07
# No VWAP data available for LYFT in 2000-08
# No VWAP data available for LYFT in 2000-09
# No VWAP data available for LYFT in 2000-10
# No VWAP data available for LYFT in 2000-11
# No VWAP data available for LYFT in 2000-12
# No VWAP data available for LYFT in 2001-01
# No VWAP data available for LYFT in 2001-02
# No VWAP data available for LYFT in 2001-03
# No VWAP data available for LYFT in 2001-04
# No VWAP data available for LYFT in 2001-05
# No VWAP data available for LYFT in 2001-06
# No VWAP data available for LYFT in 2001-07
# No VWAP data available for LYFT in 2001-08
# No VWAP data available for LYFT in 2001-09
# No VWAP data available for LYFT in 2001-10
# No VWAP data available for LYFT in 2001-11
# No VWAP data available for LYFT in 2001-12
# No VWAP data available for LYFT in 2002-01
# No VWAP data available for LYFT in 2002-02
# No VWAP data available for LYFT in 2002-03
# No VWAP data available for LYFT in 2002-04
# No VWAP data available for LYFT in 2002-05
# No VWAP data available for LYFT in 2002-06
# No VWAP data available for LYFT in 2002-07
# No VWAP data available for LYFT in 2002-08
# No VWAP data available for LYFT in 2002-09
# No VWAP data available for LYFT in 2002-10
# No VWAP data available for LYFT in 2002-11
# No VWAP data available for LYFT in 2002-12
# No VWAP data available for LYFT in 2003-01
# No VWAP data available for LYFT in 2003-02
# No VWAP data available for LYFT in 2003-03
# No VWAP data available for LYFT in 2003-04
# No VWAP data available for LYFT in 2003-05
# No VWAP data available for LYFT in 2003-06
# No VWAP data available for LYFT in 2003-07
# No VWAP data available for LYFT in 2003-08
# No VWAP data available for LYFT in 2003-09
# No VWAP data available for LYFT in 2003-10
# No VWAP data available for LYFT in 2003-11
# No VWAP data available for LYFT in 2003-12
# No VWAP data available for LYFT in 2004-01
# No VWAP data available for LYFT in 2004-02
# No VWAP data available for LYFT in 2004-03
# No VWAP data available for LYFT in 2004-04
# No VWAP data available for LYFT in 2004-05
# No VWAP data available for LYFT in 2004-06
# No VWAP data available for LYFT in 2004-07
# No VWAP data available for LYFT in 2004-08
# No VWAP data available for LYFT in 2004-09
# No VWAP data available for LYFT in 2004-10
# No VWAP data available for LYFT in 2004-11
# No VWAP data available for LYFT in 2004-12
# No VWAP data available for LYFT in 2005-01
# No VWAP data available for LYFT in 2005-02
# No VWAP data available for LYFT in 2005-03
# No VWAP data available for LYFT in 2005-04
# No VWAP data available for LYFT in 2005-05
# No VWAP data available for LYFT in 2005-06
# No VWAP data available for LYFT in 2005-07
# No VWAP data available for LYFT in 2005-08
# No VWAP data available for LYFT in 2005-09
# No VWAP data available for LYFT in 2005-10
# No VWAP data available for LYFT in 2005-11
# No VWAP data available for LYFT in 2005-12
# No VWAP data available for LYFT in 2006-01
# No VWAP data available for LYFT in 2006-02
# No VWAP data available for LYFT in 2006-03
# No VWAP data available for LYFT in 2006-04
# No VWAP data available for LYFT in 2006-05
# No VWAP data available for LYFT in 2006-06
# No VWAP data available for LYFT in 2006-07
# No VWAP data available for LYFT in 2006-08
# No VWAP data available for LYFT in 2006-09
# No VWAP data available for LYFT in 2006-10
# No VWAP data available for LYFT in 2006-11
# No VWAP data available for LYFT in 2006-12
# No VWAP data available for LYFT in 2007-01
# No VWAP data available for LYFT in 2007-02
# No VWAP data available for LYFT in 2007-03
# No VWAP data available for LYFT in 2007-04
# No VWAP data available for LYFT in 2007-05
# No VWAP data available for LYFT in 2007-06
# No VWAP data available for LYFT in 2007-07
# No VWAP data available for LYFT in 2007-08
# No VWAP data available for LYFT in 2007-09
# No VWAP data available for LYFT in 2007-10
# No VWAP data available for LYFT in 2007-11
# No VWAP data available for LYFT in 2007-12
# No VWAP data available for LYFT in 2008-01
# No VWAP data available for LYFT in 2008-02
# No VWAP data available for LYFT in 2008-03
# No VWAP data available for LYFT in 2008-04
# No VWAP data available for LYFT in 2008-05
# No VWAP data available for LYFT in 2008-06
# No VWAP data available for LYFT in 2008-07
# No VWAP data available for LYFT in 2008-08
# No VWAP data available for LYFT in 2008-09
# No VWAP data available for LYFT in 2008-10
# No VWAP data available for LYFT in 2008-11
# No VWAP data available for LYFT in 2008-12
# No VWAP data available for LYFT in 2009-01
# No VWAP data available for LYFT in 2009-02
# No VWAP data available for LYFT in 2009-03
# No VWAP data available for LYFT in 2009-04
# No VWAP data available for LYFT in 2009-05
# No VWAP data available for LYFT in 2009-06
# No VWAP data available for LYFT in 2009-07
# No VWAP data available for LYFT in 2009-08
# No VWAP data available for LYFT in 2009-09
# No VWAP data available for LYFT in 2009-10
# No VWAP data available for LYFT in 2009-11
# No VWAP data available for LYFT in 2009-12
# No VWAP data available for LYFT in 2010-01
# No VWAP data available for LYFT in 2010-02
# No VWAP data available for LYFT in 2010-03
# No VWAP data available for LYFT in 2010-04
# No VWAP data available for LYFT in 2010-05
# No VWAP data available for LYFT in 2010-06
# No VWAP data available for LYFT in 2010-07
# No VWAP data available for LYFT in 2010-08
# No VWAP data available for LYFT in 2010-09
# No VWAP data available for LYFT in 2010-10
# No VWAP data available for LYFT in 2010-11
# No VWAP data available for LYFT in 2010-12
# No VWAP data available for LYFT in 2011-01
# No VWAP data available for LYFT in 2011-02
# No VWAP data available for LYFT in 2011-03
# No VWAP data available for LYFT in 2011-04
# No VWAP data available for LYFT in 2011-05
# No VWAP data available for LYFT in 2011-06
# No VWAP data available for LYFT in 2011-07
# No VWAP data available for LYFT in 2011-08
# No VWAP data available for LYFT in 2011-09
# No VWAP data available for LYFT in 2011-10
# No VWAP data available for LYFT in 2011-11
# No VWAP data available for LYFT in 2011-12
# No VWAP data available for LYFT in 2012-01
# No VWAP data available for LYFT in 2012-02
# No VWAP data available for LYFT in 2012-03
# No VWAP data available for LYFT in 2012-04
# No VWAP data available for LYFT in 2012-05
# No VWAP data available for LYFT in 2012-06
# No VWAP data available for LYFT in 2012-07
# No VWAP data available for LYFT in 2012-08
# No VWAP data available for LYFT in 2012-09
# No VWAP data available for LYFT in 2012-10
# No VWAP data available for LYFT in 2012-11
# No VWAP data available for LYFT in 2012-12
# No VWAP data available for LYFT in 2013-01
# No VWAP data available for LYFT in 2013-02
# No VWAP data available for LYFT in 2013-03
# No VWAP data available for LYFT in 2013-04
# No VWAP data available for LYFT in 2013-05
# No VWAP data available for LYFT in 2013-06
# No VWAP data available for LYFT in 2013-07
# No VWAP data available for LYFT in 2013-08
# No VWAP data available for LYFT in 2013-09
# No VWAP data available for LYFT in 2013-10
# No VWAP data available for LYFT in 2013-11
# No VWAP data available for LYFT in 2013-12
# No VWAP data available for LYFT in 2014-01
# No VWAP data available for LYFT in 2014-02
# No VWAP data available for LYFT in 2014-03
# No VWAP data available for LYFT in 2014-04
# No VWAP data available for LYFT in 2014-05
# No VWAP data available for LYFT in 2014-06
# No VWAP data available for LYFT in 2014-07
# No VWAP data available for LYFT in 2014-08
# No VWAP data available for LYFT in 2014-09
# No VWAP data available for LYFT in 2014-10
# No VWAP data available for LYFT in 2014-11
# No VWAP data available for LYFT in 2014-12
# No VWAP data available for LYFT in 2015-01
# No VWAP data available for LYFT in 2015-02
# No VWAP data available for LYFT in 2015-03
# No VWAP data available for LYFT in 2015-04
# No VWAP data available for LYFT in 2015-05
# No VWAP data available for LYFT in 2015-06
# No VWAP data available for LYFT in 2015-07
# No VWAP data available for LYFT in 2015-08
# No VWAP data available for LYFT in 2015-09
# No VWAP data available for LYFT in 2015-10
# No VWAP data available for LYFT in 2015-11
# No VWAP data available for LYFT in 2015-12
# No VWAP data available for LYFT in 2016-01
# No VWAP data available for LYFT in 2016-02
# No VWAP data available for LYFT in 2016-03
# No VWAP data available for LYFT in 2016-04
# No VWAP data available for LYFT in 2016-05
# No VWAP data available for LYFT in 2016-06
# No VWAP data available for LYFT in 2016-07
# No VWAP data available for LYFT in 2016-08
# No VWAP data available for LYFT in 2016-09
# No VWAP data available for LYFT in 2016-10
# No VWAP data available for LYFT in 2016-11
# No VWAP data available for LYFT in 2016-12
# No VWAP data available for LYFT in 2017-01
# No VWAP data available for LYFT in 2017-02
# No VWAP data available for LYFT in 2017-03
# No VWAP data available for LYFT in 2017-04
# No VWAP data available for LYFT in 2017-05
# No VWAP data available for LYFT in 2017-06
# No VWAP data available for LYFT in 2017-07
# No VWAP data available for LYFT in 2017-08
# No VWAP data available for LYFT in 2017-09
# No VWAP data available for LYFT in 2017-10
# No VWAP data available for LYFT in 2017-11
# No VWAP data available for LYFT in 2017-12
# No VWAP data available for LYFT in 2018-01
# No VWAP data available for LYFT in 2018-02
# No VWAP data available for LYFT in 2018-03
# No VWAP data available for LYFT in 2018-04
# No VWAP data available for LYFT in 2018-05
# No VWAP data available for LYFT in 2018-06
# No VWAP data available for LYFT in 2018-07
# No VWAP data available for LYFT in 2018-08
# No VWAP data available for LYFT in 2018-09
# No VWAP data available for LYFT in 2018-10
# No VWAP data available for LYFT in 2018-11
# No VWAP data available for LYFT in 2018-12
# No VWAP data available for LYFT in 2019-01
# No VWAP data available for LYFT in 2019-02
# No VWAP data available for UBER in 2000-01
# No VWAP data available for UBER in 2000-02
# No VWAP data available for UBER in 2000-03
# No VWAP data available for UBER in 2000-04
# No VWAP data available for UBER in 2000-05
# No VWAP data available for UBER in 2000-06
# No VWAP data available for UBER in 2000-07
# No VWAP data available for UBER in 2000-08
# No VWAP data available for UBER in 2000-09
# No VWAP data available for UBER in 2000-10
# No VWAP data available for UBER in 2000-11
# No VWAP data available for UBER in 2000-12
# No VWAP data available for UBER in 2001-01
# No VWAP data available for UBER in 2001-02
# No VWAP data available for UBER in 2001-03
# No VWAP data available for UBER in 2001-04
# No VWAP data available for UBER in 2001-05
# No VWAP data available for UBER in 2001-06
# No VWAP data available for UBER in 2001-07
# No VWAP data available for UBER in 2001-08
# No VWAP data available for UBER in 2001-09
# No VWAP data available for UBER in 2001-10
# No VWAP data available for UBER in 2001-11
# No VWAP data available for UBER in 2001-12
# No VWAP data available for UBER in 2002-01
# No VWAP data available for UBER in 2002-02
# No VWAP data available for UBER in 2002-03
# No VWAP data available for UBER in 2002-04
# No VWAP data available for UBER in 2002-05
# No VWAP data available for UBER in 2002-06
# No VWAP data available for UBER in 2002-07
# No VWAP data available for UBER in 2002-08
# No VWAP data available for UBER in 2002-09
# No VWAP data available for UBER in 2002-10
# No VWAP data available for UBER in 2002-11
# No VWAP data available for UBER in 2002-12
# No VWAP data available for UBER in 2003-01
# No VWAP data available for UBER in 2003-02
# No VWAP data available for UBER in 2003-03
# No VWAP data available for UBER in 2003-04
# No VWAP data available for UBER in 2003-05
# No VWAP data available for UBER in 2003-06
# No VWAP data available for UBER in 2003-07
# No VWAP data available for UBER in 2003-08
# No VWAP data available for UBER in 2003-09
# No VWAP data available for UBER in 2003-10
# No VWAP data available for UBER in 2003-11
# No VWAP data available for UBER in 2003-12
# No VWAP data available for UBER in 2004-01
# No VWAP data available for UBER in 2004-02
# No VWAP data available for UBER in 2004-03
# No VWAP data available for UBER in 2004-04
# No VWAP data available for UBER in 2004-05
# No VWAP data available for UBER in 2011-02
# No VWAP data available for UBER in 2011-03
# No VWAP data available for UBER in 2011-04
# No VWAP data available for UBER in 2011-05
# No VWAP data available for UBER in 2011-06
# No VWAP data available for UBER in 2011-07
# No VWAP data available for UBER in 2011-08
# No VWAP data available for UBER in 2011-09
# No VWAP data available for UBER in 2011-10
# No VWAP data available for UBER in 2011-11
# No VWAP data available for UBER in 2011-12
# No VWAP data available for UBER in 2012-01
# No VWAP data available for UBER in 2012-02
# No VWAP data available for UBER in 2012-03
# No VWAP data available for UBER in 2012-04
# No VWAP data available for UBER in 2012-05
# No VWAP data available for UBER in 2012-06
# No VWAP data available for UBER in 2012-07
# No VWAP data available for UBER in 2012-08
# No VWAP data available for UBER in 2012-09
# No VWAP data available for UBER in 2012-10
# No VWAP data available for UBER in 2012-11
# No VWAP data available for UBER in 2012-12
# No VWAP data available for UBER in 2013-01
# No VWAP data available for UBER in 2013-02
# No VWAP data available for UBER in 2013-03
# No VWAP data available for UBER in 2013-04
# No VWAP data available for UBER in 2013-05
# No VWAP data available for UBER in 2013-06
# No VWAP data available for UBER in 2013-07
# No VWAP data available for UBER in 2013-08
# No VWAP data available for UBER in 2013-09
# No VWAP data available for UBER in 2013-10
# No VWAP data available for UBER in 2013-11
# No VWAP data available for UBER in 2013-12
# No VWAP data available for UBER in 2014-01
# No VWAP data available for UBER in 2014-02
# No VWAP data available for UBER in 2014-03
# No VWAP data available for UBER in 2014-04
# No VWAP data available for UBER in 2014-05
# No VWAP data available for UBER in 2014-06
# No VWAP data available for UBER in 2014-07
# No VWAP data available for UBER in 2014-08
# No VWAP data available for UBER in 2014-09
# No VWAP data available for UBER in 2014-10
# No VWAP data available for UBER in 2014-11
# No VWAP data available for UBER in 2014-12
# No VWAP data available for UBER in 2015-01
# No VWAP data available for UBER in 2015-02
# No VWAP data available for UBER in 2015-03
# No VWAP data available for UBER in 2015-04
# No VWAP data available for UBER in 2015-05
# No VWAP data available for UBER in 2015-06
# No VWAP data available for UBER in 2015-07
# No VWAP data available for UBER in 2015-08
# No VWAP data available for UBER in 2015-09
# No VWAP data available for UBER in 2015-10
# No VWAP data available for UBER in 2015-11
# No VWAP data available for UBER in 2015-12
# No VWAP data available for UBER in 2016-01
# No VWAP data available for UBER in 2016-02
# No VWAP data available for UBER in 2016-03
# No VWAP data available for UBER in 2016-04
# No VWAP data available for UBER in 2016-05
# No VWAP data available for UBER in 2016-06
# No VWAP data available for UBER in 2016-07
# No VWAP data available for UBER in 2016-08
# No VWAP data available for UBER in 2016-09
# No VWAP data available for UBER in 2016-10
# No VWAP data available for UBER in 2016-11
# No VWAP data available for UBER in 2016-12
# No VWAP data available for UBER in 2017-01
# No VWAP data available for UBER in 2017-02
# No VWAP data available for UBER in 2017-03
# No VWAP data available for UBER in 2017-04
# No VWAP data available for UBER in 2017-05
# No VWAP data available for UBER in 2017-06
# No VWAP data available for UBER in 2017-07
# No VWAP data available for UBER in 2017-08
# No VWAP data available for UBER in 2017-09
# No VWAP data available for UBER in 2017-10
# No VWAP data available for UBER in 2017-11
# No VWAP data available for UBER in 2017-12
# No VWAP data available for UBER in 2018-01
# No VWAP data available for UBER in 2018-02
# No VWAP data available for UBER in 2018-03
# No VWAP data available for UBER in 2018-04
# No VWAP data available for UBER in 2018-05
# No VWAP data available for UBER in 2018-06
# No VWAP data available for UBER in 2018-07
# No VWAP data available for UBER in 2018-08
# No VWAP data available for UBER in 2018-09
# No VWAP data available for UBER in 2018-10
# No VWAP data available for UBER in 2018-11
# No VWAP data available for UBER in 2018-12
# No VWAP data available for UBER in 2019-01
# No VWAP data available for UBER in 2019-02
# No VWAP data available for UBER in 2019-03
# No VWAP data available for UBER in 2019-04
#                      Daily VWAP Symbol
# 2000-01-03 09:00:00     58.6033    IBM
# 2000-01-03 10:00:00     58.7577    IBM
# 2000-01-03 11:00:00     58.8316    IBM
# 2000-01-03 12:00:00     58.8316    IBM
# 2000-01-03 13:00:00     58.8429    IBM
# ...                         ...    ...
# 2024-05-10 15:00:00     67.0542   UBER
# 2024-05-10 16:00:00     67.0107   UBER
# 2024-05-10 17:00:00     67.0102   UBER
# 2024-05-10 18:00:00     67.0022   UBER
# 2024-05-10 19:00:00     66.9911   UBER
#
# [2753964 rows x 2 columns]

# %% [markdown]
# MACD:

# %%
load_dotenv()

apikey = os.getenv("apikey")

def fetch_macd_daily(base_url, apikey, symbols, start_year, start_month):
    all_macd_data = pd.DataFrame() 

    for symbol in symbols: 
        start_date = datetime(start_year, start_month, 1)
        current_date = datetime.now().replace(day=1)

        while start_date < current_date:
            month_str = start_date.strftime('%Y-%m')
            macd_url = f'{base_url}function=MACD&symbol={symbol}&interval=daily&time_period=10&series_type=open&apikey={apikey}&month={month_str}'
            try:
                response = requests.get(macd_url)
                response.raise_for_status() 
                data = response.json()
            except requests.RequestException as e:
                print(f"Failed to retrieve MACD data for {symbol} in {month_str}: {e}")
                continue 

            if 'Technical Analysis: MACD' in data:
                macd_data = data['Technical Analysis: MACD']
                df = pd.DataFrame({date: values['MACD'] for date, values in macd_data.items()}, index=[0]).T
                df.index = pd.to_datetime(df.index)
                df.columns = ['Daily MACD']
                df['Daily MACD'] = df['Daily MACD'].astype(float)
                df['Symbol'] = symbol 

                all_macd_data = pd.concat([all_macd_data, df])
            else:
                print(f"No MACD data available for {symbol} in {month_str}")

            start_date += timedelta(days=32)
            start_date = start_date.replace(day=1)

            time.sleep(1) 
            
    return all_macd_data

daily_macd_data_df = fetch_macd_daily(base_url, apikey, symbols, 2000, 1)

daily_macd_data_df
# Out:
# No MACD data available for V in 2017-09
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b965d0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b95310>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d40850>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d43490>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d426d0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117e6a9d0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d41dd0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d41bd0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d43590>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b94bd0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b95cd0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117e6a890>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b97690>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b95cd0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b946d0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d400d0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d41ed0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117ad9190>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117e68c10>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d41490>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d43b90>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d41290>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x11796e290>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b96710>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117e6ac10>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b975d0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b97b50>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b952d0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d40710>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d42b90>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d42850>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117e69950>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d41250>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d42490>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d43410>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117df69d0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b97ad0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b96d10>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b95c50>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b94550>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b94650>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x1037477d0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d400d0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d42bd0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117e68ed0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117ad94d0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d42a90>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d41b10>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d41a50>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b95150>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b97190>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b95310>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b965d0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b95890>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d40a10>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d40290>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117adaed0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117e69c50>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117e80b50>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d43490>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d40650>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d43a90>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b94b90>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117e6ba10>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b968d0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b95750>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b97010>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d430d0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d42dd0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117e2d950>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117e68dd0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117ad9310>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d42390>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d43890>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d41a50>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b97f90>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b950d0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b96a10>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b97850>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b95850>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d43f10>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d43190>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117ad9610>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117e6b590>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117adb190>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d42890>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d43bd0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d40750>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b95790>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b95e50>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b96010>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b947d0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b95810>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d43b90>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d41d10>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117ad92d0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117e68f10>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d40450>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d42110>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d40250>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117adab50>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b945d0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b975d0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b96b90>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b97f90>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b94fd0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d42710>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# ...
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d2abd0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d40890>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117df65d0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117b96510>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117fef2d0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d41190>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d41d50>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d41150>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117ad9310>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117e690d0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117fed7d0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117ad9390>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117c09e10>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d28b50>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117f2b790>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117f29290>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d41c50>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117d43410>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117f2a8d0>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# Failed to retrieve MACD data for PG in 2022-03: HTTPSConnectionPool(host='www.alphavantage.co', port=443): Max retries exceeded with url: /query?function=MACD&symbol=PG&interval=daily&time_period=10&series_type=open&apikey=301IW51XB5CRM1QD&month=2022-03 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x117f29f50>: Failed to resolve 'www.alphavantage.co' ([Errno 8] nodename nor servname provided, or not known)"))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 42
#      38             time.sleep(1)
#      40     return all_macd_data
# ---> 42 daily_macd_data_df = fetch_macd_daily(base_url, apikey, symbols, 2000, 1)
#      44 daily_macd_data_df
#
# Cell In[23], line 16, in fetch_macd_daily(base_url, apikey, symbols, start_year, start_month)
#      14 macd_url = f'{base_url}function=MACD&symbol={symbol}&interval=daily&time_period=10&series_type=open&apikey={apikey}&month={month_str}'
#      15 try:
# ---> 16     response = requests.get(macd_url)
#      17     response.raise_for_status()
#      18     data = response.json()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# Daily Technical Indicators:

# %%
start_date = datetime(2000, 1, 1)
end_date = datetime.now().replace(day=1)

daily_macd_data_df = daily_macd_data_df[(daily_macd_data_df.index >= start_date) & (daily_macd_data_df.index < end_date)]
daily_vwap_data = daily_vwap_data[(daily_vwap_data.index >= start_date) & (daily_vwap_data.index < end_date)]
daily_rsi_data_df = daily_rsi_data_df[(daily_rsi_data_df.index >= start_date) & (daily_rsi_data_df.index < end_date)]

daily_macd_data_df.index = daily_macd_data_df.index.normalize()
daily_vwap_data.index = daily_vwap_data.index.normalize()
daily_rsi_data_df.index = daily_rsi_data_df.index.normalize()

combined_df = pd.merge(daily_macd_data_df, daily_vwap_data, how='inner', left_index=True, right_index=True)
combined_df = pd.merge(combined_df, daily_rsi_data_df, how='inner', left_index=True, right_index=True)

daily_technical_indicators_combined_df = combined_df[~combined_df.index.duplicated(keep='first')]

daily_technical_indicators_combined_df
# Out:
#             Daily MACD  Daily VWAP  Daily RSI
# 2024-01-02      2.4353    162.4933    61.4287
# 2024-01-03      2.1528    159.5297    48.9172
# 2024-01-04      1.8459    158.8627    44.6138
# 2024-01-05      1.5602    157.5377    42.9455
# 2024-01-08      1.2230    157.4423    36.9099
# ...                ...         ...        ...
# 2024-04-25     -2.9381    166.6323    14.6350
# 2024-04-26     -3.8716    167.6987    14.1911
# 2024-04-29     -4.5667    165.7713    14.1232
# 2024-04-30     -5.1311    165.5237    13.4707
# 2024-05-01     -5.5781    164.2557    12.8890
#
# [84 rows x 3 columns]

# %% [markdown]
# Quarterly Technical Indicators:

# %% [markdown]
# ### Ratios

# %% [markdown]
# Debt to Equity Ratio:

# %%
balance_sheet_url = f"{base_url}function=BALANCE_SHEET&symbol={symbol}&apikey={apikey}"
balance_sheet_response = requests.get(balance_sheet_url)

if balance_sheet_response.status_code == 200:
    balance_sheet_data = balance_sheet_response.json()
    
    fiscal_date_endings = []
    total_assets = []
    total_liabilities = []
    total_shareholder_equity = []
    
    for report in balance_sheet_data["quarterlyReports"]:
        fiscal_date_endings.append(report['fiscalDateEnding'])
        total_liabilities.append(float(report.get('totalLiabilities', "0")))
        total_shareholder_equity.append(float(report.get('totalShareholderEquity', "0")))
    
    debt_to_equity_ratios = [liabilities / equity if equity != 0 else 0 for liabilities, equity in zip(total_liabilities, total_shareholder_equity)]
    
    debt_to_equity_ratio_df = pd.DataFrame({
        'Symbol': [symbol] * len(fiscal_date_endings),
        'Fiscal Date Ending': fiscal_date_endings,
        'Debt to Equity Ratio': debt_to_equity_ratios
    })

debt_to_equity_ratio_df
# Out:
#    Symbol Fiscal Date Ending  Debt to Equity Ratio
# 0     IBM         2024-03-31              4.893857
# 1     IBM         2023-12-31              4.998358
# 2     IBM         2023-09-30              4.599671
# 3     IBM         2023-06-30              4.952119
# 4     IBM         2023-03-31              5.182559
# 5     IBM         2022-12-31              4.795024
# 6     IBM         2022-09-30              5.265142
# 7     IBM         2022-06-30              5.565768
# 8     IBM         2022-03-31              5.992756
# 9     IBM         2021-12-31              5.978784
# 10    IBM         2021-09-30              5.482185
# 11    IBM         2021-06-30              5.685307
# 12    IBM         2021-03-31              5.943055
# 13    IBM         2020-12-31              6.566199
# 14    IBM         2020-09-30              6.261505
# 15    IBM         2020-06-30              6.496618
# 16    IBM         2020-03-31              6.664083
# 17    IBM         2019-12-31              6.295379
# 18    IBM         2019-09-30              7.324794
# 19    IBM         2019-06-30              7.757212
# 20    IBM         2019-03-31              6.936472
# 21    IBM         2018-12-31              6.337938
# 22    IBM         2018-09-30              5.159270
# 23    IBM         2018-06-30              5.560151
# 24    IBM         2018-03-31              5.889849
# 25    IBM         2017-12-31              6.117483
# 26    IBM         2017-09-30              5.190758
# 27    IBM         2017-06-30              5.535100
# 28    IBM         2017-03-31              5.404431
# 29    IBM         2016-12-31              5.430122
# 30    IBM         2016-09-30              5.787596
# 31    IBM         2016-06-30              6.493803
# 32    IBM         2016-03-31              6.953702
# 33    IBM         2015-12-31              6.736152
# 34    IBM         2015-09-30              7.160975
# 35    IBM         2015-06-30              7.226834
# 36    IBM         2015-03-31              8.215715
# 37    IBM         2014-12-31              8.868975
# 38    IBM         2014-09-30              7.331813
# 39    IBM         2014-06-30              6.146113
# 40    IBM         2014-03-31              6.377190
# 41    IBM         2013-12-31              4.532029
# 42    IBM         2013-09-30              4.922121
# 43    IBM         2013-06-30              5.478092
# 44    IBM         2013-03-31              5.135345
# 45    IBM         2012-12-31              5.314369
# 46    IBM         2012-09-30              4.368971
# 47    IBM         2012-06-30              4.555930
# 48    IBM         2012-03-31              4.568040
# 49    IBM         2011-12-31              4.776889
# 50    IBM         2011-09-30              3.937957
# 51    IBM         2011-06-30              3.902927
# 52    IBM         2011-03-31              3.977990
# 53    IBM         2010-12-31              3.917339
# 54    IBM         2010-09-30              3.813967
# 55    IBM         2010-06-30              3.905409
# 56    IBM         2010-03-31              3.769754
# 57    IBM         2009-12-31              3.810885
# 58    IBM         2009-09-30              4.630463
# 59    IBM         2009-06-30              5.733550

# %% [markdown]
# Inventory Turnover

# %%
def fetch_financial_data(base_url, apikey, symbol):
    balance_sheet_url = f"{base_url}function=BALANCE_SHEET&symbol={symbol}&apikey={apikey}"
    income_statement_url = f"{base_url}function=INCOME_STATEMENT&symbol={symbol}&apikey={apikey}"

    balance_response = requests.get(balance_sheet_url)
    balance_data = balance_response.json() if balance_response.status_code == 200 else {}

    income_response = requests.get(income_statement_url)
    income_data = income_response.json() if income_response.status_code == 200 else {}

    fiscal_date_endings = []
    inventory_turnovers = []

    if 'quarterlyReports' in balance_data and 'quarterlyReports' in income_data:
        balance_reports = balance_data['quarterlyReports']
        income_reports = {report['fiscalDateEnding']: float(report['costofGoodsAndServicesSold']) for report in income_data['quarterlyReports']}

        for report in balance_reports:
            date = report['fiscalDateEnding']
            if date in income_reports:
                inventory = float(report.get('inventory', '0'))
                cogs = income_reports[date]

                current_index = balance_reports.index(report)
                previous_inventory = float(balance_reports[current_index - 1].get('inventory', '0')) if current_index > 0 else inventory
                average_inventory = (inventory + previous_inventory) / 2

                inventory_turnover = cogs / average_inventory if average_inventory != 0 else 0
                fiscal_date_endings.append(date)
                inventory_turnovers.append(inventory_turnover)

    inventory_turnover_df = pd.DataFrame({
        'Symbol': [symbol] * len(fiscal_date_endings),
        'Fiscal Date Ending': fiscal_date_endings,
        'Inventory Turnover': inventory_turnovers
    })

    return inventory_turnover_df

inventory_turnover_df = fetch_financial_data(base_url, apikey, 'IBM')
inventory_turnover_df
# Out:
#    Symbol Fiscal Date Ending  Inventory Turnover
# 0     IBM         2024-03-31            0.023102
# 1     IBM         2023-12-31            0.094395
# 2     IBM         2023-09-30            0.032813
# 3     IBM         2023-06-30            0.042069
# 4     IBM         2023-03-31            0.019330
# 5     IBM         2022-12-31            0.120444
# 6     IBM         2022-09-30            0.034071
# 7     IBM         2022-06-30            0.069005
# 8     IBM         2022-03-31            0.010983
# 9     IBM         2021-12-31            0.051971
# 10    IBM         2021-09-30            0.027684
# 11    IBM         2021-06-30            0.055706
# 12    IBM         2021-03-31            0.032462
# 13    IBM         2020-12-31            0.099451
# 14    IBM         2020-09-30            0.034034
# 15    IBM         2020-06-30            0.061289
# 16    IBM         2020-03-31            0.041587
# 17    IBM         2019-12-31            0.227313
# 18    IBM         2019-09-30            0.045032
# 19    IBM         2019-06-30            0.042812
# 20    IBM         2019-03-31            0.031286
# 21    IBM         2018-12-31            6.413553
# 22    IBM         2018-09-30            5.568112
# 23    IBM         2018-06-30            5.944429
# 24    IBM         2018-03-31            6.194564
# 25    IBM         2017-12-31            6.811751
# 26    IBM         2017-09-30            6.090468
# 27    IBM         2017-06-30            6.158069
# 28    IBM         2017-03-31            6.289449
# 29    IBM         2016-12-31            6.699557
# 30    IBM         2016-09-30            6.065814
# 31    IBM         2016-06-30            6.018161
# 32    IBM         2016-03-31            5.783704
# 33    IBM         2015-12-31            6.402345
# 34    IBM         2015-09-30            6.075221
# 35    IBM         2015-06-30            5.762837
# 36    IBM         2015-03-31            5.102009
# 37    IBM         2014-12-31            5.390130
# 38    IBM         2014-09-30            5.053151
# 39    IBM         2014-06-30            5.181082
# 40    IBM         2014-03-31            4.865248
# 41    IBM         2013-12-31            5.488040
# 42    IBM         2013-09-30            5.028322
# 43    IBM         2013-06-30            5.133374
# 44    IBM         2013-03-31            5.179626
# 45    IBM         2012-12-31            5.876805
# 46    IBM         2012-09-30            5.235789
# 47    IBM         2012-06-30            4.947605
# 48    IBM         2012-03-31            4.829463
# 49    IBM         2011-12-31            5.416713
# 50    IBM         2011-09-30            5.214150
# 51    IBM         2011-06-30            5.352559
# 52    IBM         2011-03-31            5.273721
# 53    IBM         2010-12-31            5.795959
# 54    IBM         2010-09-30            5.127387
# 55    IBM         2010-06-30            4.839587
# 56    IBM         2010-03-31            4.925962
# 57    IBM         2009-12-31            5.493822
# 58    IBM         2009-09-30            5.014683
# 59    IBM         2009-06-30            4.722551

# %% [markdown]
# ROI

# %%
def fetch_roa_data(base_url, apikey, symbol):
    balance_sheet_url = f"{base_url}function=BALANCE_SHEET&symbol={symbol}&apikey={apikey}"
    income_statement_url = f"{base_url}function=INCOME_STATEMENT&symbol={symbol}&apikey={apikey}"

    balance_response = requests.get(balance_sheet_url)
    balance_data = balance_response.json() if balance_response.status_code == 200 else {}

    income_response = requests.get(income_statement_url)
    income_data = income_response.json() if income_response.status_code == 200 else {}

    fiscal_date_endings = []
    roa_values = []

    if 'quarterlyReports' in balance_data and 'quarterlyReports' in income_data:
        balance_reports = {report['fiscalDateEnding']: float(report['totalAssets']) for report in balance_data['quarterlyReports']}
        income_reports = {report['fiscalDateEnding']: float(report['netIncome']) for report in income_data['quarterlyReports']}

        for date, assets in balance_reports.items():
            if date in income_reports:
                net_income = income_reports[date]
                roa = (net_income / assets) * 100 if assets != 0 else 0
                fiscal_date_endings.append(date)
                roa_values.append(roa)

    roa_df = pd.DataFrame({
        'Symbol': [symbol] * len(fiscal_date_endings),
        'Fiscal Date Ending': fiscal_date_endings,
        'ROA (%)': roa_values
    })

    return roa_df

roa_df = fetch_roa_data(base_url, apikey, 'IBM')
roa_df
# Out:
#    Symbol Fiscal Date Ending   ROA (%)
# 0     IBM         2024-03-31  1.170089
# 1     IBM         2023-12-31  2.431215
# 2     IBM         2023-09-30  1.317651
# 3     IBM         2023-06-30  1.197310
# 4     IBM         2023-03-31  0.693670
# 5     IBM         2022-12-31  2.129783
# 6     IBM         2022-09-30 -2.539531
# 7     IBM         2022-06-30  1.091739
# 8     IBM         2022-03-31  0.549991
# 9     IBM         2021-12-31  1.767411
# 10    IBM         2021-09-30  0.783558
# 11    IBM         2021-06-30  0.902502
# 12    IBM         2021-03-31  0.642539
# 13    IBM         2020-12-31  0.869392
# 14    IBM         2020-09-30  1.101682
# 15    IBM         2020-06-30  0.882620
# 16    IBM         2020-03-31  0.765956
# 17    IBM         2019-12-31  2.411523
# 18    IBM         2019-09-30  1.117498
# 19    IBM         2019-06-30  1.615239
# 20    IBM         2019-03-31  1.215190
# 21    IBM         2018-12-31  1.581268
# 22    IBM         2018-09-30  2.208378
# 23    IBM         2018-06-30  1.976616
# 24    IBM         2018-03-31  1.340144
# 25    IBM         2017-12-31 -0.840805
# 26    IBM         2017-09-30  2.241113
# 27    IBM         2017-06-30  1.934520
# 28    IBM         2017-03-31  1.489425
# 29    IBM         2016-12-31  3.831617
# 30    IBM         2016-09-30  2.467865
# 31    IBM         2016-06-30  2.121027
# 32    IBM         2016-03-31  1.694487
# 33    IBM         2015-12-31  4.044436
# 34    IBM         2015-09-30  2.712956
# 35    IBM         2015-06-30  3.057421
# 36    IBM         2015-03-31  2.076814
# 37    IBM         2014-12-31  4.673960
# 38    IBM         2014-09-30  0.013119
# 39    IBM         2014-06-30  3.325933
# 40    IBM         2014-03-31  1.944213
# 41    IBM         2013-12-31  4.919732
# 42    IBM         2013-09-30  3.427553
# 43    IBM         2013-06-30  2.800709
# 44    IBM         2013-03-31  2.584557
# 45    IBM         2012-12-31  4.890910
# 46    IBM         2012-09-30  3.300282
# 47    IBM         2012-06-30  3.407653
# 48    IBM         2012-03-31  2.654946
# 49    IBM         2011-12-31  4.714900
# 50    IBM         2011-09-30  3.484177
# 51    IBM         2011-06-30  3.227083
# 52    IBM         2011-03-31  2.532224
# 53    IBM         2010-12-31  4.630505
# 54    IBM         2010-09-30  3.346334
# 55    IBM         2010-06-30  3.273061
# 56    IBM         2010-03-31  2.472245
# 57    IBM         2009-12-31  4.414705
# 58    IBM         2009-09-30  3.100072
# 59    IBM         2009-06-30  2.993584

# %% [markdown]
# ### Economic Indicators

# %% [markdown]
# Inflation

# %%
inflation_url = f"{base_url}function=INFLATION&symbol={symbol}&apikey={apikey}"
inflation_response = requests.get(inflation_url)

if inflation_response.status_code == 200:
    inflation_data = inflation_response.json()
    
    report_date = []
    inflation_rate = []
    
    for value in inflation_data["data"]:
        report_date.append(value['date'])
        inflation_rate.append(value['value'])
    
    inflation_rates_df = pd.DataFrame({
        'Date': report_date,
        'Inflation Rate': inflation_rate
    })

inflation_rates_df
# Out:
#           Date    Inflation Rate
# 0   2022-01-01  8.00279982052121
# 1   2021-01-01  4.69785886363742
# 2   2020-01-01  1.23358439630629
# 3   2019-01-01  1.81221007526021
# 4   2018-01-01  2.44258329692817
# ..         ...               ...
# 58  1964-01-01  1.27891156462591
# 59  1963-01-01  1.23966942148753
# 60  1962-01-01  1.19877334820186
# 61  1961-01-01  1.07072414764724
# 62  1960-01-01  1.45797598627791
#
# [63 rows x 2 columns]

# %% [markdown]
# Unemployment

# %%
unemployment_url = f"{base_url}function=UNEMPLOYMENT&symbol={symbol}&apikey={apikey}"
unemployment_response = requests.get(unemployment_url)

if unemployment_response.status_code == 200:
    unemployment_data = unemployment_response.json()
    
    report_date = []
    unemployment_rate = []
    
    for value in unemployment_data["data"]:
        report_date.append(value['date'])
        unemployment_rate.append(value['value'])
    
    unemployment_rates_df = pd.DataFrame({
        'Date': report_date,
        'Unemployment Rate': unemployment_rate
    })

unemployment_rates_df
# Out:
#            Date Unemployment Rate
# 0    2024-04-01               3.9
# 1    2024-03-01               3.8
# 2    2024-02-01               3.9
# 3    2024-01-01               3.7
# 4    2023-12-01               3.7
# ..          ...               ...
# 911  1948-05-01               3.5
# 912  1948-04-01               3.9
# 913  1948-03-01               4.0
# 914  1948-02-01               3.8
# 915  1948-01-01               3.4
#
# [916 rows x 2 columns]

# %% [markdown]
# GPD

# %%
gdp_url = f"{base_url}function=GDP&symbol={symbol}&apikey={apikey}"
gdp_response = requests.get(gdp_url)

if gdp_response.status_code == 200:
    gdp_data = unemployment_response.json()
    
    report_date = []
    gdp_rate = []
    
    for value in gdp_data["data"]:
        report_date.append(value['date'])
        gdp_rate.append(value['value'])
    
    gdp_rates_df = pd.DataFrame({
        'Date': report_date,
        'GDP Rate': gdp_rate
    })

gdp_rates_df
# Out:
#            Date GDP Rate
# 0    2024-04-01      3.9
# 1    2024-03-01      3.8
# 2    2024-02-01      3.9
# 3    2024-01-01      3.7
# 4    2023-12-01      3.7
# ..          ...      ...
# 911  1948-05-01      3.5
# 912  1948-04-01      3.9
# 913  1948-03-01      4.0
# 914  1948-02-01      3.8
# 915  1948-01-01      3.4
#
# [916 rows x 2 columns]

# %% [markdown]
# ## Company Overview

# %%
dfs = []

for symbol in symbols:
    company_overview_url = f"{base_url}function=OVERVIEW&symbol={symbol}&apikey={apikey}"
    company_overview_response = requests.get(company_overview_url)

    if company_overview_response.status_code == 200:
        company_overview_data = company_overview_response.json()

        company_overview_selected_data = {
            "Symbol": company_overview_data.get("Symbol", ""),
            "Name": company_overview_data.get("Name", ""),
            "Industry": company_overview_data.get("Industry", ""),
            "Address": company_overview_data.get("Address", "")
        }

        temp_df = pd.DataFrame([company_overview_selected_data])
        address_parts = temp_df['Address'].str.split(', ', expand=True)
        temp_df['Street Address'] = address_parts.get(0, "")
        temp_df['City'] = address_parts.get(1, "")
        temp_df['State'] = address_parts.get(2, "")
        temp_df['Country'] = address_parts.get(3, "")
        temp_df = temp_df.drop(columns=['Address'])

        dfs.append(temp_df)

company_overview_df = pd.concat(dfs, ignore_index=True)

company_overview_df = company_overview_df.dropna(how='all')

company_overview_df
# Out:
#    Symbol                             Name  \
# 0     IBM  International Business Machines
# 1    AAPL                        Apple Inc
# 2    MSFT            Microsoft Corporation
# 3    AMZN                   Amazon.com Inc
# 4   GOOGL             Alphabet Inc Class A
# 5    META              Meta Platforms Inc.
# 6     JPM              JPMorgan Chase & Co
# 7       V                Visa Inc. Class A
# 8      PG         Procter & Gamble Company
# 9     UNH  UnitedHealth Group Incorporated
# 10    JNJ                Johnson & Johnson
# 11    XOM                 Exxon Mobil Corp
# 12    CVX                     Chevron Corp
# 13   TSLA                        Tesla Inc
# 14    WMT                      Walmart Inc
# 15    BAC             Bank of America Corp
# 16   INTC                Intel Corporation
# 17   CSCO                Cisco Systems Inc
# 18     KO            The Coca-Cola Company
# 19    PEP                      PepsiCo Inc
# 20    MCD           McDonald’s Corporation
# 21    MMM                       3M Company
# 22     BA               The Boeing Company
# 23    CAT                  Caterpillar Inc
# 24    LMT      Lockheed Martin Corporation
# 25     GS          Goldman Sachs Group Inc
# 26    DIS              Walt Disney Company
# 27    PFE                       Pfizer Inc
# 28    MRK              Merck & Company Inc
# 29     GE                     GE Aerospace
# 30    NKE                         Nike Inc
# 31   SBUX            Starbucks Corporation
# 32   NFLX                      Netflix Inc
# 33   ORCL               Oracle Corporation
# 34    AMD       Advanced Micro Devices Inc
# 35   NVDA               NVIDIA Corporation
# 36      F               Ford Motor Company
# 37     GM           General Motors Company
# 38    UPS        United Parcel Service Inc
# 39    FDX                FedEx Corporation
# 40   LYFT                         LYFT Inc
# 41   UBER            Uber Technologies Inc
#
#                                              Industry  \
# 0                         COMPUTER & OFFICE EQUIPMENT
# 1                                ELECTRONIC COMPUTERS
# 2                       SERVICES-PREPACKAGED SOFTWARE
# 3                  RETAIL-CATALOG & MAIL-ORDER HOUSES
# 4   SERVICES-COMPUTER PROGRAMMING, DATA PROCESSING...
# 5   SERVICES-COMPUTER PROGRAMMING, DATA PROCESSING...
# 6                           NATIONAL COMMERCIAL BANKS
# 7                     SERVICES-BUSINESS SERVICES, NEC
# 8   SOAP, DETERGENTS, CLEANG PREPARATIONS, PERFUME...
# 9                    HOSPITAL & MEDICAL SERVICE PLANS
# 10                        PHARMACEUTICAL PREPARATIONS
# 11                                 PETROLEUM REFINING
# 12                                 PETROLEUM REFINING
# 13              MOTOR VEHICLES & PASSENGER CAR BODIES
# 14                              RETAIL-VARIETY STORES
# 15                          NATIONAL COMMERCIAL BANKS
# 16                   SEMICONDUCTORS & RELATED DEVICES
# 17                  COMPUTER COMMUNICATIONS EQUIPMENT
# 18                                          BEVERAGES
# 19                                          BEVERAGES
# 20                               RETAIL-EATING PLACES
# 21         SURGICAL & MEDICAL INSTRUMENTS & APPARATUS
# 22                                           AIRCRAFT
# 23                     CONSTRUCTION MACHINERY & EQUIP
# 24           GUIDED MISSILES & SPACE VEHICLES & PARTS
# 25    SECURITY BROKERS, DEALERS & FLOTATION COMPANIES
# 26      SERVICES-MISCELLANEOUS AMUSEMENT & RECREATION
# 27                        PHARMACEUTICAL PREPARATIONS
# 28                        PHARMACEUTICAL PREPARATIONS
# 29  ELECTRONIC & OTHER ELECTRICAL EQUIPMENT (NO CO...
# 30                         RUBBER & PLASTICS FOOTWEAR
# 31                    RETAIL-EATING & DRINKING PLACES
# 32                         SERVICES-VIDEO TAPE RENTAL
# 33                      SERVICES-PREPACKAGED SOFTWARE
# 34                   SEMICONDUCTORS & RELATED DEVICES
# 35                   SEMICONDUCTORS & RELATED DEVICES
# 36              MOTOR VEHICLES & PASSENGER CAR BODIES
# 37              MOTOR VEHICLES & PASSENGER CAR BODIES
# 38               TRUCKING & COURIER SERVICES (NO AIR)
# 39                               AIR COURIER SERVICES
# 40                    SERVICES-BUSINESS SERVICES, NEC
# 41                    SERVICES-BUSINESS SERVICES, NEC
#
#                       Street Address                 City          State  \
# 0                 1 NEW ORCHARD ROAD               ARMONK             NY
# 1                  ONE INFINITE LOOP            CUPERTINO             CA
# 2                  ONE MICROSOFT WAY              REDMOND             WA
# 3             410 TERRY AVENUE NORTH              SEATTLE             WA
# 4          1600 AMPHITHEATRE PARKWAY        MOUNTAIN VIEW             CA
# 5                   1601 WILLOW ROAD           MENLO PARK             CA
# 6                 383 MADISON AVENUE             NEW YORK             NY
# 7                      P.O. BOX 8999        SAN FRANCISCO             CA
# 8         ONE PROCTER & GAMBLE PLAZA           CINCINNATI             OH
# 9          UNITEDHEALTH GROUP CENTER  9900 BREN ROAD EAST    MINNEAPOLIS
# 10         ONE JOHNSON & JOHNSON PLZ        NEW BRUNSWICK             NJ
# 11             5959 LAS COLINAS BLVD               IRVING             TX
# 12        6001 BOLLINGER CANYON ROAD            SAN RAMON             CA
# 13                3500 DEER CREEK RD            PALO ALTO             CA
# 14              702 SOUTHWEST 8TH ST          BENTONVILLE             AR
# 15  BANK OF AMERICA CORPORATE CENTER       100 N TRYON ST      CHARLOTTE
# 16         2200 MISSION COLLEGE BLVD            RNB-4-151    SANTA CLARA
# 17                170 WEST TASMAN DR             SAN JOSE             CA
# 18               ONE COCA COLA PLAZA              ATLANTA             GA
# 19              700 ANDERSON HILL RD             PURCHASE             NY
# 20        110 NORTH CARPENTER STREET              CHICAGO             IL
# 21                         3M CENTER    BLDG. 220-13E-26A        ST PAUL
# 22             P O BOX 3707 MS 1F 31              SEATTLE             WA
# 23                510 LAKE COOK ROAD            SUITE 100      DEERFIELD
# 24                 6801 ROCKLEDGE DR             BETHESDA             MD
# 25                   200 WEST STREET             NEW YORK             NY
# 26      500 SOUTH BUENA VISTA STREET              BURBANK             CA
# 27                     235 E 42ND ST             NEW YORK             NY
# 28          2000 GALLOPING HILL ROAD           KENILWORTH             NJ
# 29              41 FARNSWORTH STREET               BOSTON             MA
# 30                   ONE BOWERMAN DR            BEAVERTON             OR
# 31                     P O BOX 34067              SEATTLE             WA
# 32             100 WINCHESTER CIRCLE                    .      LOS GATOS
# 33                500 ORACLE PARKWAY     MAIL STOP 5 OP 7   REDWOOD CITY
# 34              2485 AUGUSTINE DRIVE          SANTA CLARA             CA
# 35         2701 SAN TOMAS EXPRESSWAY          SANTA CLARA             CA
# 36                 ONE AMERICAN ROAD             DEARBORN             MI
# 37            300 RENAISSANCE CENTER              DETROIT             MI
# 38            55 GLENLAKE PARKWAY NE              ATLANTA             GA
# 39        942 SOUTH SHADY GROVE ROAD              MEMPHIS             TN
# 40                  185 BERRY STREET           SUITE 5000  SAN FRANCISCO
# 41                   1455 MARKET ST.            4TH FLOOR  SAN FRANCISCO
#
#    Country
# 0       US
# 1       US
# 2       US
# 3       US
# 4       US
# 5       US
# 6       US
# 7       US
# 8       US
# 9       MN
# 10      US
# 11      US
# 12      US
# 13      US
# 14      US
# 15      NC
# 16      CA
# 17      US
# 18      US
# 19      US
# 20      US
# 21      MN
# 22      US
# 23      IL
# 24      US
# 25      US
# 26      US
# 27      US
# 28      US
# 29      US
# 30      US
# 31      US
# 32      CA
# 33      CA
# 34      US
# 35      US
# 36      US
# 37      US
# 38      US
# 39      US
# 40      CA
# 41      CA

# %% [markdown]
# ## Financial Statements

# %%
quarterly_reports_df['Fiscal Date Ending'] = pd.to_datetime(quarterly_reports_df['Fiscal Date Ending'])
income_statements_df['Fiscal Date Ending'] = pd.to_datetime(income_statements_df['Fiscal Date Ending'])
cash_flows_df['Fiscal Date Ending'] = pd.to_datetime(cash_flows_df['Fiscal Date Ending'])

combined_df = pd.merge(quarterly_reports_df, income_statements_df, on=['Symbol', 'Fiscal Date Ending'], how='outer')
combined_df = pd.merge(combined_df, cash_flows_df, on=['Symbol', 'Fiscal Date Ending'], how='outer')

financial_statements_df = combined_df[combined_df['Fiscal Date Ending'] >= '2009-06-30']

financial_statements_df.sort_values('Fiscal Date Ending', inplace=True)

financial_statements_df
# Out:
# /var/folders/kf/x49nrq891g3dcplsvlw9bh4r0000gn/T/ipykernel_10058/3766564765.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_statements_df.sort_values('Fiscal Date Ending', inplace=True)
#    Symbol Fiscal Date Ending  Total Assets Total Liabilities  \
# 59    IBM         2009-06-30  103655000000       88182000000
# 58    IBM         2009-09-30  103675000000       85182000000
# 57    IBM         2009-12-31  109022000000       86267000000
# 56    IBM         2010-03-31  105208000000       83059000000
# 55    IBM         2010-06-30  103420000000       82244000000
# 54    IBM         2010-09-30  107174000000       84815000000
# 53    IBM         2010-12-31  113452000000       90279000000
# 52    IBM         2011-03-31  112960000000       90185000000
# 51    IBM         2011-06-30  113474000000       90263000000
# 50    IBM         2011-09-30  110158000000       87781000000
# 49    IBM         2011-12-31  116433000000       96197000000
# 48    IBM         2012-03-31  115347000000       94563000000
# 47    IBM         2012-06-30  113832000000       93269000000
# 46    IBM         2012-09-30  115778000000       94112000000
# 45    IBM         2012-12-31  119213000000      100229000000
# 44    IBM         2013-03-31  117258000000       98044000000
# 43    IBM         2013-06-30  115153000000       97269000000
# 42    IBM         2013-09-30  117845000000       97837000000
# 41    IBM         2013-12-31  125641000000      103294000000
# 40    IBM         2014-03-31  122646000000      105906000000
# 39    IBM         2014-06-30  124314000000      106801000000
# 38    IBM         2014-09-30  118911000000      104515000000
# 37    IBM         2014-12-31  117271000000      105257000000
# 36    IBM         2015-03-31  112037000000       99747000000
# 35    IBM         2015-06-30  112729000000       98892000000
# 43         3.932000e+09         1.320000e+08        -2.279000e+09
# 42         4.746000e+09        -1.431000e+09         2.100000e+08
# 41         6.528000e+09        -1.728000e+09        -1.988000e+09
# 40         3.326000e+09         9.960000e+08        -3.683000e+09
# 39         4.605000e+09         1.800000e+07        -1.164000e+09
# 38         1.800000e+07         3.500000e+08        -1.730000e+09
# 37        -6.490000e+08        -1.820000e+08        -4.610000e+09
# 36         4.045000e+09         1.530000e+09        -2.314000e+09
# 35         9.240000e+08        -8.890000e+08        -1.290000e+09
# 34         4.235000e+09        -2.780000e+08        -5.780000e+08
# 33         5.526000e+09        -4.371000e+09        -3.340000e+08
# 32         5.530000e+09        -7.860000e+08         4.056000e+09
# 31         3.458000e+09        -3.726000e+09        -1.900000e+09
# 30         4.117000e+09        -1.830000e+08        -2.848000e+09
# 29         3.979000e+09        -2.666000e+09         3.100000e+07
# 28         3.955000e+09         1.043000e+09        -8.130000e+08
# 27         3.466000e+09        -9.830000e+08         7.940000e+08
# 26         3.570000e+09        -1.058000e+09        -1.361000e+09
# 25         5.733000e+09        -2.854000e+09         4.680000e+08
# 24         4.602000e+09        -8.940000e+08        -1.527000e+09
# 23         2.294000e+09         2.960000e+08        -1.082000e+09
# 22         4.232000e+09        -2.157000e+09         9.950000e+08
# 21         4.119000e+09         1.237000e+09        -3.189000e+09
# 20         4.759000e+09        -3.140000e+08         3.260000e+09
# 19         2.941000e+09         4.745000e+09         2.246700e+10
# 18         3.619000e+09        -2.978500e+10        -6.741000e+09
# 17         3.451000e+09         7.040000e+08        -4.237000e+09
# 16         4.476000e+09        -2.720000e+08         1.325000e+09
# 15         3.576000e+09        -6.510000e+08        -1.740000e+08
# 14         4.285000e+09         3.930000e+08        -2.360000e+08
# 13         5.860000e+09         1.200000e+08        -4.839000e+09
# 12         4.914000e+09        -1.506000e+09        -4.326000e+09
# 11         2.625000e+09        -2.111000e+09        -1.664000e+09
# 10         2.713000e+09        -7.100000e+07        -2.770000e+08
# 9          2.544000e+09        -2.250000e+08        -1.218000e+09
# 8          3.248000e+09        -1.077000e+09         2.852000e+09
# 7          1.321000e+09         5.110000e+08        -2.708000e+09
# 6          1.901000e+09        -1.380000e+09         2.204000e+09
# 5          3.965000e+09        -9.100000e+08        -1.358000e+09
# 4          3.774000e+09        -7.660000e+09         7.205000e+09
# 3          2.638000e+09         3.710000e+08        -1.220000e+09
# 2          3.056000e+09        -1.672000e+09        -1.617000e+09
# 1          4.463000e+09         3.136000e+09        -9.700000e+07
# 0          4.168000e+09        -3.971000e+09         3.399000e+09

# %% [markdown]
# ## Key Financial Ratios

# %%
combined_df = pd.merge(debt_to_equity_ratio_df, inventory_turnover_df, on=['Symbol', 'Fiscal Date Ending'], how='inner')

key_financial_ratios_df = pd.merge(combined_df, roa_df, on=['Symbol', 'Fiscal Date Ending'], how='inner')

key_financial_ratios_df
# Out:
#    Symbol Fiscal Date Ending  Debt to Equity Ratio  Inventory Turnover  \
# 0     IBM         2024-03-31              4.893857            0.023102
# 1     IBM         2023-12-31              4.998358            0.094395
# 6  -2.539531
# 7   1.091739
# 8   0.549991
# 9   1.767411
# 10  0.783558
# 11  0.902502
# 12  0.642539
# 13  0.869392
# 14  1.101682
# 15  0.882620
# 16  0.765956
# 17  2.411523
# 18  1.117498
# 19  1.615239
# 20  1.215190
# 21  1.581268
# 22  2.208378
# 23  1.976616
# 24  1.340144
# 25 -0.840805
# 26  2.241113
# 27  1.934520
# 28  1.489425
# 29  3.831617
# 30  2.467865
# 31  2.121027
# 32  1.694487
# 33  4.044436
# 34  2.712956
# 35  3.057421
# 36  2.076814
# 37  4.673960
# 38  0.013119
# 39  3.325933
# 40  1.944213
# 41  4.919732
# 42  3.427553
# 43  2.800709
# 44  2.584557
# 45  4.890910
# 46  3.300282
# 47  3.407653
# 48  2.654946
# 49  4.714900
# 50  3.484177
# 51  3.227083
# 52  2.532224
# 53  4.630505
# 54  3.346334
# 55  3.273061
# 56  2.472245
# 57  4.414705
# 58  3.100072
# 59  2.993584

# %% [markdown]
# ## Accounts

# %%
balance_sheet_url = f"{base_url}function=BALANCE_SHEET&symbol={symbol}&apikey={apikey}"
balance_sheet_response = requests.get(balance_sheet_url)

if balance_sheet_response.status_code == 200:
    balance_sheet_data = balance_sheet_response.json()
    
    fiscal_date_endings = []
    current_net_receivables = []
    current_accounts_payable = []
    
    for report in balance_sheet_data["quarterlyReports"]:
        fiscal_date_endings.append(report['fiscalDateEnding'])
        current_net_receivables.append(report['currentNetReceivables'])
        current_accounts_payable.append(report['currentAccountsPayable'])
    
    quarterly_accounts_df = pd.DataFrame({
        'Symbol': [symbol] * len(fiscal_date_endings),
        'Fiscal Date Ending': fiscal_date_endings,
        'Current Net Receivables': current_net_receivables,
        'Current Accounts Payable': current_accounts_payable
    })

quarterly_accounts_df

# %% [markdown]
# ## Market Indicators

# %%
quarterly_market_indicators_data_df = daily_technical_indicators_combined_df.resample('Q').mean()

rename_dict = {col: col.replace('Daily', 'Quarterly') for col in quarterly_market_indicators_data_df.columns}

quarterly_market_indicators_data_df.rename(columns=rename_dict, inplace=True)

quarterly_market_indicators_data_df
# Out:
#             Quarterly MACD  Quarterly VWAP  Quarterly RSI
# 2024-03-31        3.694389      180.999116      63.159367
# 2024-06-30       -1.210739      180.285335      34.693057

# %% [markdown]
# ## Economic Indicators

# %%
gdp_rates_df['Date'] = pd.to_datetime(gdp_rates_df['Date'])
inflation_rates_df['Date'] = pd.to_datetime(inflation_rates_df['Date'])
unemployment_rates_df['Date'] = pd.to_datetime(unemployment_rates_df['Date'])

combined_df = pd.merge(gdp_rates_df, inflation_rates_df, on='Date', how='inner', suffixes=('', '_inflation'))

combined_df = pd.merge(combined_df, unemployment_rates_df, on='Date', how='inner', suffixes=('', '_unemployment'))

economic_indicators_df = combined_df[combined_df['Date'] >= '1960-01-01']

economic_indicators_df.rename(columns={
    'GDP Rate': 'GDP',
    'value': 'Inflation Rate',
    'value_unemployment': 'Unemployment Rate'
}, inplace=True)

economic_indicators_df.sort_values('Date', inplace=True)

economic_indicators_df
